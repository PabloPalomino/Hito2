# %% [markdown]
# # Cuestion 3 - Visualizacion de datos

# %%
Utilizando una fuente de datos, consumirla en Python para mostrar diferentes tipos de
gráficos

# %% [markdown]
# 3.1.- Grafico de barras

# %%
import pandas as pd
import matplotlib.pyplot as plt

df= pd.read_csv("https://raw.githubusercontent.com/PabloPalomino/Hito2/main/Indian_Cities_Database.csv")

top=df[0:10]

plt.pie(top["Lat"],labels=top["City"],
        startangle=320,
        radius = 1.2, autopct = '%1.2f%%')


plt.title('Latitud')
plt.show()

# %% [markdown]
# 3.2.- Grafico de barras

# %%
import pandas as pd
import matplotlib.pyplot as plt

df= pd.read_csv("https://raw.githubusercontent.com/PabloPalomino/Hito2/main/Indian_Cities_Database.csv")

top=df[0:10]

plt = top.plot.bar (y = ["Lat"], x = "City")

# %% [markdown]
# 3.3.- Grafico combinado

# %%
import pandas as pd
import matplotlib.pyplot as plt

df= pd.read_csv("https://raw.githubusercontent.com/PabloPalomino/Hito2/main/Indian_Cities_Database.csv")

top=df[0:10]

ax = top['Lat'].plot(kind='bar',grid=True)
ax2 = ax.twinx()
ax2.plot(top['Long'], linestyle='-', linewidth=2.0,color='red')
plt.show();

# %% [markdown]
# 3.4.- Grafico dinamico
#
# Como he dejado explicado en los comentarios del codigo, para poder interactuar con el grafico 3d sera necesario activar las
# lineas siguientes:
#
# from mpl_toolkits.mplot3d import  Axes3D
# %matplotlib notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Para interactuar con el grafico 3d sera necesario activar las siguientes lineas de codigo
#Al estar en el mismo archivo que el resto de graficos, Axes3D nos genera un conflicto al interferir con el resto de graficos


#from mpl_toolkits.mplot3d import  Axes3D
#%matplotlib notebook 

df= pd.read_csv("https://raw.githubusercontent.com/PabloPalomino/Hito2/main/wikidata_setin.csv")

top=df[0:10]

sns.set(style = "ticks")

fig = plt.figure(figsize = (5,5))

ax = fig.add_subplot(111, projection = '3d')

top=df[0:50]
x = top['year set']
y = top['years elapsed']
z = top['decade']


ax.scatter(x, y, z)

plt.show()
